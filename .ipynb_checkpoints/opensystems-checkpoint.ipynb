# %%
import qutip as qt
import numpy as np
import lmfit as lm
import matplotlib.pyplot as plt
from lmfit import Model

π = np.pi
_ = %precision 3

# %% [markdown]
# <div>
# <img src="attachment:Screenshot%202023-10-31%20at%201.09.13%20PM.png" width="200"/>
# </div>

# %% [markdown]
# ## Generate Bloch Vectors

# %%
def blochvector(theta, phi, p):
    r = [np.sin(theta)*np.cos(phi), np.sin(theta)*np.sin(phi), np.cos(theta)]
    bloch_sphere = qt.Bloch(figsize=(3,3))
    bloch_sphere.add_vectors(r)
    if p:
        bloch_sphere.show()
    return r

# %%
theta = π/4
phi = π/4
blochvector(theta, phi, True)
# Out:
# [0.500, 0.500, 0.707]

# %% [markdown]
# ## Convert Density Operators to Bloch Vectors

# %%
def tobloch(rho):
    a = rho[0,0]
    b = rho[1,0]
    c = rho[0,1]
    d = rho[1,1]
    
    x = 2*np.real(b)
    y = 2*np.imag(b)
    z = 2*a - 1
    
    return [x, y, z]

# %% [markdown]
# $|g\rangle=(1,0)^T$, $|e\rangle=(0,1)^T$

# %%
g_state = qt.basis(2, 0)
e_state = qt.basis(2, 1)

rho0 = e_state * e_state.dag()
tobloch(rho0)
# Out:
# [0.000, 0.000, (-1+0j)]

# %% [markdown]
# ## Bloch Vector to Density Operator

# %%
theta = π/2
phi = π/4
blochvec = blochvector(theta, phi, False)

# %%
def torho(blochvec):
    sx = qt.sigmax()
    sy = qt.sigmay()
    sz = qt.sigmaz()

    x = blochvec[0]
    y = blochvec[1]
    z = blochvec[2]

    rho = 0.5*(qt.qeye(2) + x*sx + y*sy + z*sz)
    return rho

# %% [markdown]
# ## Simple Check (not exhaustive of errors)

# %%
thetas = np.linspace(0, π, 10)
phis = np.linspace(0, 2*π, 10)

results = []
for theta in thetas:
    for phi in phis:
        blochvec = blochvector(theta, phi, False)
        results.append([blochvec, tobloch(torho(blochvec))])

# %%
results
# Out:
# [[[0.000, 0.000, 1.000], [0.000, 0.000, (1+0j)]],
#  [[0.000, 0.000, 1.000], [0.000, 0.000, (1+0j)]],
#  [[0.000, 0.000, 1.000], [0.000, 0.000, (1+0j)]],
#  [[-0.000, 0.000, 1.000], [0.000, 0.000, (1+0j)]],
#  [[-0.000, 0.000, 1.000], [0.000, 0.000, (1+0j)]],
#  [[-0.000, -0.000, 1.000], [0.000, 0.000, (1+0j)]],
#  [[-0.000, -0.000, 1.000], [0.000, 0.000, (1+0j)]],
#  [[0.000, -0.000, 1.000], [0.000, 0.000, (1+0j)]],
#  [[0.000, -0.000, 1.000], [0.000, 0.000, (1+0j)]],
#  [[0.000, -0.000, 1.000], [0.000, 0.000, (1+0j)]],
#  [[0.342, 0.000, 0.940], [0.342, 0.000, (0.9396926207859084+0j)]],
#  [[0.262, 0.220, 0.940], [0.262, 0.220, (0.9396926207859084+0j)]],
#  [[0.059, 0.337, 0.940], [0.059, 0.337, (0.9396926207859084+0j)]],
#  [[-0.171, 0.296, 0.940], [-0.171, 0.296, (0.9396926207859084+0j)]],
#  [[-0.321, 0.117, 0.940], [-0.321, 0.117, (0.9396926207859084+0j)]],
#  [[-0.321, -0.117, 0.940], [-0.321, -0.117, (0.9396926207859084+0j)]],
#  [[-0.171, -0.296, 0.940], [-0.171, -0.296, (0.9396926207859084+0j)]],
#  [[0.059, -0.337, 0.940], [0.059, -0.337, (0.9396926207859084+0j)]],
#  [[0.262, -0.220, 0.940], [0.262, -0.220, (0.9396926207859084+0j)]],
#  [[0.342, -0.000, 0.940], [0.342, 0.000, (0.9396926207859084+0j)]],
.000, -1.000], [0.000, 0.000, (-1+0j)]],
#  [[0.000, 0.000, -1.000], [0.000, 0.000, (-1+0j)]],
#  [[0.000, 0.000, -1.000], [0.000, 0.000, (-1+0j)]],
#  [[-0.000, 0.000, -1.000], [0.000, 0.000, (-1+0j)]],
#  [[-0.000, 0.000, -1.000], [0.000, 0.000, (-1+0j)]],
#  [[-0.000, -0.000, -1.000], [0.000, 0.000, (-1+0j)]],
#  [[-0.000, -0.000, -1.000], [0.000, 0.000, (-1+0j)]],
#  [[0.000, -0.000, -1.000], [0.000, 0.000, (-1+0j)]],
#  [[0.000, -0.000, -1.000], [0.000, 0.000, (-1+0j)]],
#  [[0.000, -0.000, -1.000], [0.000, 0.000, (-1+0j)]]]

# %% [markdown]
# # Test 1

# %% [markdown]
# $\rho_0 = |\psi\rangle \langle\psi|$
#
# $L_1 = \sigma^- = |0\rangle \langle1|$,  $\gamma_1 = \gamma$,  $\gamma_{\alpha\ge2} = 0$,  $H = 0$

# %%
theta = π - π/8
phi = π/4 - π/8
blochvec = blochvector(theta, phi, True)
rho0 = torho(blochvec)

a = qt.destroy(2)
gamma = 0.1
c_ops = [np.sqrt(gamma) * a]

# %%
times = np.linspace(0, 100, 1000)
H = qt.Qobj([[0,0], [0,0]])
result = qt.mesolve(H, rho0, times, c_ops)

# %%
result.states[-1]
# Out:
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[1.000e+00+0.j 1.191e-03-0.j]
#  [1.191e-03+0.j 4.366e-05+0.j]]

# %%
xs = []
ys = []
zs = []

for state in result.states:
    xs.append(qt.expect(sx, state))
    ys.append(qt.expect(sy, state))
    zs.append(qt.expect(sz, state))

# %%
fig, ax = plt.subplots()
plt.plot(times, xs, label='<x>')
plt.plot(times, ys, label='<y>')
plt.plot(times, zs, label='<z>')
_ = ax.axhline(y=0, color='r', linestyle='--', label='y=0')
plt.legend()
plt.xlabel('Time', fontsize=12)
plt.ylabel('Probability', fontsize=12)
plt.title(r'Expectation Values of $\rho_0$ Overtime under $H=0$, $L_1=\sigma^-$, $\gamma=0.1$', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Expectation Values of $\\rho_0$ Overtime under $H=0$, $L_1=\\sigma^-$, $\\gamma=0.1$')

# %%
#exact functional form of amplitude decay of an underdamped harmonic oscillator
def decay1(t, A, gamma):
    return A * np.exp(-0.5*(gamma*t))

model = Model(decay1)
params = model.make_params(A=1, gamma=0.5)
result = model.fit(xs, params, t=times)

# %%
fig = plt.figure()
_ = plt.hist(result.params['A']*np.exp(-0.5*(result.params['gamma']*times)) - xs)
_ = plt.xlabel('Deviation Between Fitted and Simulated Expectations')
_ = plt.ylabel('Counts')
_ = plt.title('Fit Result')

# %%
#exact functional form of amplitude decay of an underdamped harmonic oscillator
def decay2(t, A, gamma):
    return 1 + ((A-1)*np.exp(-1*(gamma*t)))

model = Model(decay2)
params = model.make_params(A=1, gamma=0.5)
result = model.fit(zs, params, t=times)

fig = plt.figure()
_ = plt.hist(1+((result.params['A']-1)*np.exp(-1*(result.params['gamma']*times))) - zs)
_ = plt.xlabel('Deviation Between Fitted and Simulated Expectations')
_ = plt.ylabel('Counts')
_ = plt.title('Fit Result')

# %% [markdown]
# # Test 2

# %% [markdown]
# $\rho_0 = |\psi\rangle \langle\psi|$
#
# $L_1 = \sigma^-_1 \otimes \mathbb{1}_2 = |0\rangle_1 \langle1|_1 \otimes \mathbb{1}_2$,  $\gamma_1 = 0.1$,  $\gamma_{\alpha\ge2} = 0$
#
# $H/\hbar = {\frac{\omega_1}{2} a^\dagger a + \frac{\omega_2}{2} b^\dagger b } + g(a^\dagger b + b^\dagger a).$

# %%
psi0 = qt.tensor(g_state, e_state)
rho0 = psi0 * psi0.dag()

a = qt.tensor(qt.destroy(2), qt.qeye(2))
gamma = 0.1
c_ops = [np.sqrt(gamma) * a]

gg_proj = qt.tensor(g_state, g_state).proj()
ge_proj = qt.tensor(g_state, e_state).proj()
eg_proj = qt.tensor(e_state, g_state).proj()
ee_proj = qt.tensor(e_state, e_state).proj()

def hamiltonian(omega_1, omega_2, g):
    t1 = omega_1 / 2 * adag * a
    t2 = omega_2 / 2 * bdag * b
    t3 = g * ((adag * b) + (bdag * a))
    return t1 + t2 + t3

omega = 2*π * 6000 #6 Ghz converted to microsecond timescale
g = π 

h_onres = hamiltonian(omega_1=omega, omega_2=omega, g=g)
times = np.linspace(0, 15, 601)

# %%
result = qt.mesolve(h_onres, rho0, times, c_ops)

# %%
result.states[0].ptrace(0)
# Out:
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[1. 0.]
#  [0. 0.]]

# %%
zs = []
for state in result.states:
    zs.append(qt.expect(sz, state.ptrace(0)))

# %%
plt.plot(times, zs)

# %%
def fn(t, A, gamma, omega, delta):
    return A * np.exp(-1*(gamma*t)) * np.cos(omega*t-delta)

model = Model(fn)
params = model.make_params(A=1, gamma=0.5, omega=omega, delta=3)
result = model.fit(zs, params, t=times)

# %%
result
# Out:
# <h2>Fit Result</h2> <p>Model: Model(fn)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>123</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>601</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>4</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 124.687044</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 0.20885602</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-937.245577</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-919.651197</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.26463023</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>A</td><td style='text-align:left'> 1.36034957</td><td style='text-align:left'> 0.10370155</td><td style='text-align:left'>(7.62%)</td><td style='text-align:left'>1.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>gamma</td><td style='text-align:left'> 0.23055701</td><td style='text-align:left'> 0.03929542</td><td style='text-align:left'>(17.04%)</td><td style='text-align:left'>0.5</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>omega</td><td style='text-align:left'> 37705.2700</td><td style='text-align:left'> 0.04819842</td><td style='text-align:left'>(0.00%)</td><td style='text-align:left'>37699.11184307752</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>delta</td><td style='text-align:left'>-0.44888601</td><td style='text-align:left'> 0.07944903</td><td style='text-align:left'>(17.70%)</td><td style='text-align:left'>3.0</td><td style='text-align:left'>       -inf</td><td style='text-align:left'>        inf</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>gamma</td><td style='text-align:left'>omega</td><td style='text-align:right'>-0.7850</td></tr><tr><td style='text-align:left'>omega</td><td style='text-align:left'>delta</td><td style='text-align:right'>+0.7738</td></tr><tr><td style='text-align:left'>gamma</td><td style='text-align:left'>delta</td><td style='text-align:right'>-0.6194</td></tr><tr><td style='text-align:left'>A</td><td style='text-align:left'>gamma</td><td style='text-align:right'>+0.6126</td></tr><tr><td style='text-align:left'>A</td><td style='text-align:left'>omega</td><td style='text-align:right'>-0.2273</td></tr><tr><td style='text-align:left'>A</td><td style='text-align:left'>delta</td><td style='text-align:right'>-0.2017</td></tr></table>

# %%
plt.plot(times, 
         (
        result.params['A'].value) * 
         (np.exp(-1*(result.params['gamma'].value*times))) * 
         np.cos((result.params['omega'].value*times)-result.params['delta'].value)
        )
